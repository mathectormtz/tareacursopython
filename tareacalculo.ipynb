# %% [markdown]
# <a href="https://colab.research.google.com/github/mathectormtz/tareacursopython/blob/main/tareacalculo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# tarea paramétricas

# %%
from sympy import symbols, sin, cos, pi
from sympy import plot_parametric
t = symbols('t')
def x(t):
  return (cos(t)+(1/2)*(cos(7*t))+(1/3)*sin(17*t))
def y(t):
  return (sin(t)+(1/2)*(sin(7*t))+(1/3)*cos(17*t))

plot_parametric((x(t), y(t), (t, 0, 14*pi)));

# %% [markdown]
# tarea grafica 1

# %%
from sympy import symbols, Eq
from sympy import plot_implicit
x, y = symbols('x y')
plot_implicit(Eq(x**2+y**3-2*y-3, 0), (x, -15, 15),
                 (y, -15, 15));

# %% [markdown]
# tarea grafica 2

# %%
from sympy import symbols, Eq
from sympy import plot_implicit
import numpy as np
paso = .01
y = np.arange(-1, 1, paso)
# quite el cero
y = y[y!=0]
x, y = symbols('x y')
plot_implicit(Eq((x+(5/(y**2)))*(y-(3/100)) -9.7, 0), (x, -15, 15),
                  (y, -15, 15));

# %% [markdown]
# tarea derivada

# %%
from sympy import symbols, diff, sin, tan, exp, sqrt
x = symbols('x')
diff(tan(((exp(2*(sin (x))))/4*x)**(sqrt (x))), x)
# Out:
# (x*exp(2*sin(x))/4)**(sqrt(x))*(4*(x*exp(2*sin(x))*cos(x)/2 + exp(2*sin(x))/4)*exp(-2*sin(x))/sqrt(x) + log(x*exp(2*sin(x))/4)/(2*sqrt(x)))*(tan((x*exp(2*sin(x))/4)**(sqrt(x)))**2 + 1)

# %% [markdown]
# graficación de composiciones

# %%
from sympy import symbols, sin, Abs, ln
from sympy.plotting import plot
def f(x):
  return sqrt (-x)

def g(x):
  return ln(x)

x = symbols('x')

plot(f(g(x)))
plot(g(f(x)))
plot((f(x))*(g(x)))

# %% [markdown]
# grafica polares

# %%
from re import A
from sympy import symbols
import numpy as np
import matplotlib.pyplot as plt


theta = np.linspace(0, 2*np.pi, 4000)
r = A * (1+ np.cos(theta))
x = r * np.sin(theta)
y = r * np.cos(theta)

plt.axis('off');
plt.axis('equal');
plt.plot(x,y);

# %% [markdown]
# grafica segunda función polar

# %%
from re import A
from sympy import symbols
import numpy as np
import matplotlib.pyplot as plt

theta = np.linspace(1, 4 * np.pi, 4000)
r = (A/theta)

plt.polar(theta, r, marker='+',color=(.2,.4,.5,.3) );
plt.show();

# %% [markdown]
# tarea sumatoria

# %%
from re import A
from sympy import symbols, sin, pi
from sympy.plotting import plot
x = symbols('x')


fx = 1
for k in range(100):
  fx = fx + ((sin (2*pi*(k**2)*x))/(4))
n = 100  # Número de términos en la sumatoria
suma = 0

for k in range(1, n + 1):
  suma += (x**2)/(2*k)


print(fx)
print(suma)
# Out:
# sin(2*pi*x)/4 + sin(8*pi*x)/4 + sin(18*pi*x)/4 + sin(32*pi*x)/4 + sin(50*pi*x)/4 + sin(72*pi*x)/4 + sin(98*pi*x)/4 + sin(128*pi*x)/4 + sin(162*pi*x)/4 + sin(200*pi*x)/4 + sin(242*pi*x)/4 + sin(288*pi*x)/4 + sin(338*pi*x)/4 + sin(392*pi*x)/4 + sin(450*pi*x)/4 + sin(512*pi*x)/4 + sin(578*pi*x)/4 + sin(648*pi*x)/4 + sin(722*pi*x)/4 + sin(800*pi*x)/4 + sin(882*pi*x)/4 + sin(968*pi*x)/4 + sin(1058*pi*x)/4 + sin(1152*pi*x)/4 + sin(1250*pi*x)/4 + sin(1352*pi*x)/4 + sin(1458*pi*x)/4 + sin(1568*pi*x)/4 + sin(1682*pi*x)/4 + sin(1800*pi*x)/4 + sin(1922*pi*x)/4 + sin(2048*pi*x)/4 + sin(2178*pi*x)/4 + sin(2312*pi*x)/4 + sin(2450*pi*x)/4 + sin(2592*pi*x)/4 + sin(2738*pi*x)/4 + sin(2888*pi*x)/4 + sin(3042*pi*x)/4 + sin(3200*pi*x)/4 + sin(3362*pi*x)/4 + sin(3528*pi*x)/4 + sin(3698*pi*x)/4 + sin(3872*pi*x)/4 + sin(4050*pi*x)/4 + sin(4232*pi*x)/4 + sin(4418*pi*x)/4 + sin(4608*pi*x)/4 + sin(4802*pi*x)/4 + sin(5000*pi*x)/4 + sin(5202*pi*x)/4 + sin(5408*pi*x)/4 + sin(5618*pi*x)/4 + sin(5832*pi*x)/4 + sin
# ...

# %% [markdown]
# tarea integral

# %%
from sympy import symbols, Integral, sqrt

x = symbols('x')
intsen  = Integral(sqrt(1+x**3),(x,-1,1))
print("El resultado de la integral es:", intsen.evalf())
# Out:
# El resultado de la integral es: 1.95275723372785

# %% [markdown]
# tarea limites

# %%
from sympy import symbols, limit, sqrt
x = symbols('x')
limit((x**2-4)/(sqrt(x+7)-((3/2)*(sqrt(x+2)))), x , 2)
# Out:
# -96/5
