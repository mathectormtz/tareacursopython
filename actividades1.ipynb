# %% [markdown]
# <a href="https://colab.research.google.com/github/mathectormtz/tareacursopython/blob/main/actividades1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Actividad Integral

# %%
from sympy import symbols, Integral, sin

x = symbols('x')
intsen  = Integral(sin(x),(x,-1,1))
print("El resultado es:", intsen.evalf())
# Out:
# El resultado es: 0.e-100

# %% [markdown]
# otra forma

# %%
from sympy import symbols, integrate, exp, oo

x = symbols('x')
print(integrate(exp(-x),(x, 0, oo)))
# Out:
# 1

# %% [markdown]
# Actividad Estadistica

# %%
from google.colab import auth
from pydrive.drive import GoogleDrive
from pydrive.auth import GoogleAuth
from oauth2client.client import GoogleCredentials

auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

myfile = drive.Createfile({'Id':'1CmgwD3kuaXvRwplgR0qEKVdp_R104-aE'})
myfile.GetContentFile('datos1.txt')

import pandas as pd
frm= pd.read_csv('datos1.txt', header=None)
print(frm.head())
print(frm.tail())
print("Que columnas tengo \n",frm.columns)
print(frm[0].describe())

# %% [markdown]
# Actividad funciones explicitas

# %%
from sympy import symbols, sin
from sympy.plotting import plot
x = symbols('x')

fx = 0
for i in range(4):
  fx = fx + sin (i*x)

print(fx)
plot(fx)
# Out:
# sin(x) + sin(2*x) + sin(3*x)

# %% [markdown]
# Actividad

# %%
from sympy import symbols, sin, Abs
from sympy.plotting import plot
def f(x):
  return Abs(Abs(x)-1)
x = symbols('x')

plot(f(x))
plot(f(f(f(x))));
plot(f(x)*f(x),(x,-5,5), line_color='red')

# %% [markdown]
# Actividad cambio

# %%
from sympy import symbols, sin, Abs, ln
from sympy.plotting import plot
def f(x):
  return (x+3)*(x-2)*(x+4)

def g(x):
  return ln(x)

x = symbols('x')

plot(f(x))
plot(f(x),  (x, -5, 3), line_color='red')
plot(g(f(x)))

# %% [markdown]
# Actividad segunda

# %%
from sympy import symbols, sin, Abs, ln
from sympy.plotting import plot
def f(x):
  return 3*(x+3)*(x-2)*(x+4)

def g(x):
  return ln(x)

x = symbols('x')

g1 = plot(f(x),  (x, -5, 5), line_color='red', show=False)
g2 = plot(g(f(x)), (x, -5, 5),line_color='blue', show=False)
g1.append(g2[0])
# g1 extend(g2)
g1.show()

# %% [markdown]
# ejemplos jueves

# %%
from sympy import symbols, Eq
from sympy import plot_implicit
x, y = symbols('x y')
plot_implicit(Eq(x**4-(x**2-y**3), 0), (x, -1.5, 1.5),
                 (y, -1.5, 1.5));

# %% [markdown]
# Grafica ecuación implicita

# %%
from sympy import sqrt, sin
from sympy import plot_implicit
plot_implicit(sin(x**5) + (x-2*y**2) > 0, (x, -2, 4),
                 (y, -2, 2));

# %% [markdown]
# ejemplo paramétricas

# %%
from sympy import symbols, sin, cos, exp, pi
from sympy import plot_parametric
t = symbols('t')
def x(t):
  return sin(t)*(exp(cos(t))-2*cos(4*t)-sin(t/12)**5)
def y(t):
  return cos(t)*(exp(cos(t))-2*cos(4*t)-sin(t/12)**5)

plot_parametric((x(t), y(t), (t, -6*pi, 6*pi)));
plot_parametric(x(t), y(t), (t, -50, 50));

# %% [markdown]
# ejemplo polares

# %%
import numpy as np
import matplotlib.pyplot as plt

theta = np.linspace(0, 2*np.pi, 4000)
r = 3 * np.cos(6 * theta)
x = r * np.sin(theta)
y = r * np.cos(theta)

plt.axis('off');
plt.axis('equal');
plt.plot(x,y);
